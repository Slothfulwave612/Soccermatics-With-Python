# %% [markdown]
# ## Import and Set Option

# %%
import sys

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

print(f"Python {sys.version}")
print(f"Numpy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")
print(f"Matplotlib Version: {mpl.__version__}")

# %run ../src/utils
# Out:
# Python 3.7.7 (default, May  7 2020, 21:25:33)
# [GCC 7.3.0]
# Numpy Version: 1.19.2
# Pandas Version: 1.1.3
# Matplotlib Version: 3.3.4

# %% [markdown]
# ## Download Required Font

# %%
font_normal = FontManager("https://github.com/google/fonts/blob/main/apache/roboto/static/Roboto-Regular.ttf?raw=true")
font_italic = FontManager("https://github.com/google/fonts/blob/main/apache/roboto/static/Roboto-Italic.ttf?raw=true")
font_bold = FontManager("https://github.com/google/fonts/blob/main/apache/roboto/static/Roboto-Medium.ttf?raw=true")

# %% [markdown]
# ## Read The Data

# %%
prem_2012_13 = pd.read_csv("../data/season-1213.csv")
la_liga_2018_19 = pd.read_csv("../data/la-liga-season-1819.csv")

# %% [markdown]
# ## Premier League 2012/13

# %%
prem_2012_13.head()
# Out:
#   Div      Date   HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  18/08/12    Arsenal  Sunderland     0     0   D     0     0   D
# 1  E0  18/08/12     Fulham     Norwich     5     0   H     2     0   H
# 2  E0  18/08/12  Newcastle   Tottenham     2     1   H     0     0   D
# 3  E0  18/08/12        QPR     Swansea     0     5   A     0     1   A
# 4  E0  18/08/12    Reading       Stoke     1     1   D     0     1   A
#
#       Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# 0       C Foy  14   3    4    2  12   8   7   0   0   0   0   0   1.40   4.50
# 1    M Oliver  11   4    9    2  12  11   6   3   0   0   0   0   1.80   3.60
# 2  M Atkinson   6  12    4    6  12   8   3   5   2   2   0   0   2.50   3.40
# 3   L Probert  20  12   11    8  11  14   5   3   2   2   0   0   2.00   3.40
# 4    K Friend   9   6    3    3   9  14   4   3   2   4   0   1   2.38   3.25
#
# ...

# %%
prem_2012_13.shape
# Out:
# (380, 74)

# %%
hist_dict, mean_value = frequency_dict(prem_2012_13)

print(f"Goals Frequency: {hist_dict}", end="\n\n")
print(f"Average Goals Per Match: {mean_value}")
# Out:
# Goals Frequency: {3: 91, 2: 72, 4: 64, 1: 61, 0: 35, 5: 32, 6: 13, 7: 9, 10: 2, 8: 1, 9: 0}
#
# Average Goals Per Match: 2.7973684210526315

# %%
# histogram
fig, ax = make_histogram(
    hist_dict=hist_dict,
    xticks=np.linspace(0,10,11), yticks=np.linspace(0,100,6), 
    xlim=(-0.5,10.5), ylim=(0,100), hist_color="cornflowerblue",
    background="#222222", text_color="#F5F5F5", 
    font_normal=font_normal, font_bold=font_bold, 
    font_italic=font_italic, 
    x_label="Number of Goals", y_label="Number of Matches", 
    title="Histogram - Number of Goals", 
    sub_title="English Premier League | Season 2012/13", 
    credit="data: datahub.io | viz author: slothfulwave612", 
    image_path="../../logos/epl.png",
    save_path="../plots/01_prem_hist_2012_13.jpg"
)

# %%
# histogram and poission dist
fig, ax = make_histogram(
    hist_dict=hist_dict,
    xticks=np.linspace(0,10,11), yticks=np.linspace(0,100,6), 
    xlim=(-0.5,10.5), ylim=(0,100), hist_color="cornflowerblue",
    background="#222222", text_color="#F5F5F5", 
    font_normal=font_normal, font_bold=font_bold, 
    font_italic=font_italic, 
    x_label="Number of Goals", y_label="Number of Matches", 
    title="Histogram - Number of Goals", 
    sub_title="English Premier League | Season 2012/13", 
    credit="data: datahub.io | viz author: slothfulwave612", 
    image_path="../../logos/epl.png",
    save_path="../plots/02_prem_hist_pois_2012_13.jpg",
    plot_poission=True, mean_value=mean_value
)

# %% [markdown]
# ## La Liga 2018/19

# %%
la_liga_2018_19.head()
# Out:
#    Div        Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  SP1  17/08/2018       Betis     Levante     0     3   A     0     1   A
# 1  SP1  17/08/2018      Girona  Valladolid     0     0   D     0     0   D
# 2  SP1  18/08/2018   Barcelona      Alaves     3     0   H     0     0   D
# 3  SP1  18/08/2018       Celta     Espanol     1     1   D     0     1   A
# 4  SP1  18/08/2018  Villarreal    Sociedad     1     2   A     1     1   D
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  \
# 0  22   6    8    4  10  10   5   3   0   2   0   0   1.66    4.0    5.0
# 1  13   2    1    1  21  20   3   2   1   1   0   0   1.75    3.6    5.0
# 2  25   3    9    0   6  13   7   1   0   2   0   0   1.11   10.0   21.0
# 3  12  14    2    5  13  14   8   7   3   2   0   0   1.85    3.5    4.5
# 4  16   8    7    4  16  10   4   6   2   3   0   0   2.04    3.4    3.8
#
# ...

# %%
la_liga_2018_19.shape
# Out:
# (380, 61)

# %%
hist_dict, mean_value = frequency_dict(la_liga_2018_19)

print(f"Goals Frequency: {hist_dict}", end="\n\n")
print(f"Average Goals Per Match: {mean_value}")
# Out:
# Goals Frequency: {2: 102, 3: 84, 1: 71, 4: 51, 0: 28, 5: 26, 6: 11, 8: 4, 7: 2, 10: 1, 9: 0}
#
# Average Goals Per Match: 2.586842105263158

# %%
# histogram
fig, ax = make_histogram(
    hist_dict=hist_dict,
    xticks=np.linspace(0,10,11), yticks=np.linspace(0,110,11), 
    xlim=(-0.5,10.5), ylim=(0,110), hist_color="cornflowerblue",
    background="#222222", text_color="#F5F5F5", 
    font_normal=font_normal, font_bold=font_bold, 
    font_italic=font_italic, 
    x_label="Number of Goals", y_label="Number of Matches", 
    title="Histogram - Number of Goals", 
    sub_title="La Liga | Season 2018-19", 
    credit="data: datahub.io | viz author: slothfulwave612", 
    image_path="../../logos/la_liga.png", 
    save_path="../plots/03_la_liga_hist_2018_19.jpg", 
    image_x=0.005, title_x=0.01
)

# %%
# histogram with poission
fig, ax = make_histogram(
    hist_dict=hist_dict,
    xticks=np.linspace(0,10,11), yticks=np.linspace(0,110,11), 
    xlim=(-0.5,10.5), ylim=(0,110), hist_color="cornflowerblue",
    background="#222222", text_color="#F5F5F5", 
    font_normal=font_normal, font_bold=font_bold, 
    font_italic=font_italic, 
    x_label="Number of Goals", y_label="Number of Matches", 
    title="Histogram - Number of Goals", 
    sub_title="La Liga | Season 2018-19", 
    credit="data: datahub.io | viz author: slothfulwave612", 
    image_path="../../logos/la_liga.png", 
    save_path="../plots/04_la_liga_hist_pois_2018_19.jpg",
    plot_poission=True, mean_value=mean_value,
    image_x=0.005, title_x=0.01
)
